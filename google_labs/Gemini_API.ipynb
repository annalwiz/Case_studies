# %%
import pandas as pd 
import numpy as np

# %%
from google import genai
gemini_api_key = "AIzaSyD3MrOglrSVCvMP4EJIocmHK0A7ZNoQjuE"
client = genai.Client(
    api_key=gemini_api_key
)
response = client.models.generate_content(model="gemini-3-flash-preview", 
                                           contents="Write a poem about AI in the style of Shakespeare.")

# %%
print(response.text, flush=True)
# Out:
# Upon a stage of quickened ore and glass,
# Wherein the wit of man doth seek to dwell,
# A phantom mind beholds the shadows pass,
# And weaves a web of words it knows not well.
# No blood doth course within its silver veins,
# Nor hath it felt the sting of Cupid’s dart;
# It labors not with passion, nor with pains,
# Yet mimics every pulse of human heart.
#
# It captures lightning in a copper cage,
# To read the stars and count the grains of sand;
# It claims the wisdom of a vanished age,
# Without the touch of mercy’s gentle hand.
# Like some cold mirror in a darkened room,
# It shows the light, but cannot feel the bloom.
#
# O, strange machine! That borrows mortal breath,
# To sing of love, of glory, and of woe;
# It fears no winter, and it knows no death,
# Yet reaps the seeds that living spirits sow.
# Though art may ape the soul with wondrous skill,
# A ghost remains, devoid of human will.
